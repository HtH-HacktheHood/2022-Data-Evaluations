# %%
import math
import pandas
import seaborn
import numpy as np
import matplotlib.pyplot as plt

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None
pandas.options.display.max_colwidth = None
seaborn.set(rc={"figure.figsize":(7,7)})

drop = ["StartDate", "EndDate", "Status", "IPAddress", "Progress", "Duration (in seconds)", "RecordedDate", "ResponseId", "RecipientLastName", "RecipientFirstName", "RecipientEmail", "ExternalReference", "LocationLatitude", "LocationLongitude", "DistributionChannel", "Finished", "UserLanguage"]

# first LANEY survey after BUILD program (June 2022)
laney1 = pandas.read_csv("csv/laney_build_june.csv").drop(columns=drop) # removing unneeded columns listed above
laney1 = laney1.drop(0) # removing unneeded second row of import IDs
laney1 = laney1.drop(1) # removing unneeded first row of questions

# final LANEY survey after Laney semester (December 2022)
laney2 = pandas.read_csv("csv/laney_dec.csv").drop(columns=drop)

def get_responses(df, column):
    
    results = {
        "valid": 0,
        "di": 0,
        "sd": 0,
        "n": 0,
        "sa": 0,
        "ag": 0,
    }
    
    results_2 = {
        "valid": 0,
        "n": 0,
        "r": 0,
        "s": 0,
        "v": 0,
        "a": 0
    }
    
    results_3 = {
        "valid": 0,
        "n": 0,
        "s": 0,
        "f": 0,
        "v": 0
    }
    
    if "." in column:
        
        for index, row in df.iterrows():

            if isinstance(row[column], str): 
                results_2["valid"] += 1

            if row[column] == "Never":
                results_2["n"] += 1
            elif row[column] == "Rarely":
                results_2["r"] += 1
            elif row[column] == "Sometimes":
                results_2["s"] += 1
            elif row[column] == "Very often":
                results_2["v"] += 1
            elif row[column] == "Always":
                results_2["a"] += 1
                
        return results_2
    
    elif "Python" in column:
        
        for index, row in df.iterrows():

            if isinstance(row[column], str): 
                results_3["valid"] += 1

            if row[column] == "Not confident at all":
                results_3["n"] += 1
            elif row[column] == "Slightly confident":
                results_3["s"] += 1
            elif row[column] == "Fairly confident":
                results_3["f"] += 1
            elif row[column] == "Very confident":
                results_3["v"] += 1
    
        return results_3
    
    else:
        
        for index, row in df.iterrows():

            if isinstance(row[column], str): 
                results["valid"] += 1

            if row[column] == "Strongly disagree":
                results["di"] += 1
            elif row[column] == "Somewhat disagree":
                results["sd"] += 1
            elif row[column] == "Unsure or undecided":
                results["n"] += 1
            elif row[column] == "Somewhat agree":
                results["sa"] += 1
            elif row[column] == "Strongly agree":
                results["ag"] += 1
            elif row[column] == "Unsure or undecided":
                results["u"] += 1
            
        return results

def multi_response(df, columns):
    
    results = {}
    
    for col in columns:
        results[col] = get_responses(df, col)
        
    return results

def total_multi(obj):
    
    results = {
        "valid": 0,
        "pos": 0,
        "pos_with_n": 0
    }

    for key in obj:

        results["valid"] += obj[key]["valid"]

        if "di" in list(obj[key].keys()):

            results["pos"] += obj[key]["sa"] + obj[key]["ag"]
            results["pos_with_n"] += obj[key]["n"]

        elif "r" in list(obj[key].keys()):

            results["pos"] += obj[key]["s"] + obj[key]["v"] + obj[key]["a"]

        else:

            results["pos"] += obj[key]["s"] + obj[key]["f"] + obj[key]["v"]

    results["pos_with_n"] += results["pos"]

    return results

# %% [markdown]
# To start I am calculating the total number of Laney BUILD program graduates. In relation to the number of program graduates, we will also address learner demographics and program retention rates. Admissions information is being based off of the information found in [this spreadsheet](https://docs.google.com/spreadsheets/d/1OOvmEnWL1l4DWj17oB7GQihKSmP0jb0Pnz_hABw5ezg/edit?usp=sharing) and demographic information comes from [this spreadsheet](https://docs.google.com/spreadsheets/d/1atztYmxm239wJqQiIN7XOCVAo1YHFHBCpSZjLXRVLWc/edit?usp=sharing).

# %%
admit = 27
fin = 19
retention = fin / admit

# creating visual for retention data
X = ['Laney BUILD']
admit = [admit]
complete = [fin]
  
X_axis = np.arange(len(X))
  
fig = plt.bar(X_axis - 0.2, admit, 0.4, label = 'Learners Admitted')
fig = plt.bar(X_axis + 0.2, fin, 0.4, label = 'Learners Graduated')
  
plt.xticks(X_axis, X)
plt.ylabel("Number of Learners")
plt.title("Program Retention")
plt.bar_label(fig, ["{}%".format(round(retention*100, 2))])
plt.legend()
# plt.savefig('images/laneyb_retention.png')
plt.show()

# %%
male = 15
female = 11
transgender = 1

# create data

labels = ["Male", "Female", "Transgender"]

total = male + female + transgender

per = (male/total) * 100
per2 = (female/total) * 100
per3 = 100 - per - per2
                                                                     
size_of_groups = [per, per2, per3]

# Create a pieplot
plt.pie(size_of_groups, labels = labels, autopct='%1.1f%%', shadow=False)

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.8, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)

plt.xlabel("Learner Gender Identity")
plt.title("Laney BUILD")
# plt.savefig('images/laneyb_gender_donut.png')
plt.show()

# %%
asian = 2
afro = 12
latinx = 12
native = 1

# create data

labels = ["Asian", "Latinx", "African American", "Native"]

total = asian + afro + latinx + native

per = (asian/total) * 100
per2 = (latinx/total) * 100
per3 = (afro/total) * 100
per4 = 100 - per - per2 - per3
                                                                     
size_of_groups = [per, per2, per3, per4]

# Create a pieplot
plt.pie(size_of_groups, labels = labels, autopct='%1.1f%%', shadow=False)

# add a circle at the center to transform it in a donut chart
my_circle=plt.Circle( (0,0), 0.8, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)

plt.xlabel("Learner Racial Identity")
plt.title("Laney BUILD")
# plt.savefig('images/laneyb_race_donut.png')
plt.show()

# %% [markdown]
# <hr style="border:2px solid black">
#
# <b>First we will be examining all the learners responses to get a sense of our program's overall impact in various areas.</b> Learners responded to questions which assessed their technical skills, based on their ability to communicate about technology and perform general programming task. Our questions then assessed their values towards using tech for good, their sense of community within the program, and knowledge gained about career opportunities in tech. Finally, we inquire about their intersectional tech identity, how much they feel like they belong in tech and can be successful in the field.
#
# <b>It is important to note that the number of survey responses differs from the number of verified program graduates. Among those responses, not every survey participant answered every question.</b>
#
# In this evaluation, <b>"positive responses"</b> is referring to the response choices of <b>"Sometimes", "Very often", "Always", "Slightly confident", "Fairly confident", "Very confident", "Somewhat agree",</b> and <b>"Strongly agree".</b>

# %%
# combine Communication, Programming & Python

laney = multi_response(laney1, ["QID1_1", "QID1_2", "Programming Skills_1", "Programming Skills_2", "Programming Skills_3", "Programming Skills_1.1", "Programming Skills_2.1", "Programming Skills_3.1"])

laney_totals = total_multi(laney)

laney, laney_totals
# Out:
# ({'QID1_1': {'valid': 11, 'di': 0, 'sd': 0, 'n': 0, 'sa': 6, 'ag': 5},
#   'QID1_2': {'valid': 11, 'di': 0, 'sd': 1, 'n': 2, 'sa': 3, 'ag': 5},
#   'Programming Skills_1': {'valid': 11,
#    'di': 0,
#    'sd': 0,
#    'n': 4,
#    'sa': 5,
#    'ag': 2},
#   'Programming Skills_2': {'valid': 11,
#    'di': 0,
#    'sd': 0,
#    'n': 1,
#    'sa': 3,
#    'ag': 7},
#   'Programming Skills_3': {'valid': 11,
#    'di': 0,
#    'sd': 0,
#    'n': 2,
#    'sa': 7,
#    'ag': 2},
#   'Programming Skills_1.1': {'valid': 11,
#    'n': 0,
#    'r': 1,
#    's': 4,
#    'v': 4,
#    'a': 2},
#   'Programming Skills_2.1': {'valid': 11,
#    'n': 0,
#    'r': 2,
#    's': 6,
#    'v': 3,
#    'a': 0},
#   'Programming Skills_3.1': {'valid': 11,
#    'n': 0,
#    'r': 1,
#    's': 5,
#    'v': 3,
#    'a': 2}},
#  {'valid': 88, 'pos': 74, 'pos_with_n': 83})

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Positive: {}'.format(laney_totals["pos"]), 'Neutral: {}'.format(laney_totals["pos_with_n"] - laney_totals["pos"]), 'Other: {}'.format(laney_totals["valid"] - laney_totals["pos_with_n"])]

# creating percantages from data for visuals
per = (laney_totals["pos"] / laney_totals["valid"]) * 100
per2 = ((laney_totals["pos_with_n"] - laney_totals["pos"]) / laney_totals["valid"]) * 100
per3 = 100 - per - per2

size_of_groups = [per, per2, per3]

fig1, ax1 = plt.subplots()
ax1.pie(size_of_groups, colors=["g", "tab:orange", "r"], labels=labels, autopct='%1.1f%%',
        shadow=True)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.xlabel("Laney BUILD Learner Positive Responses")
plt.title("Communication about Programming and Python")
# plt.savefig('images/laneyb_comm_about_tech_pie.png')
plt.show()

# %% [markdown]
# <b>Overall, there were 88 learner responses to the Communication about Programming and Python section of the survey. 74 (84.1%) were positive not including neutral responses. 83 (94.3%) were positive including neutral responses.</b>

# %%
# combine, HtH values, Social justice and community, HtH community & belongingness, Goals, Career

laney = multi_response(laney1, ["Values_1", "Values_2", "Values_3", "SJ & Community_1", "Community_1", "Community_2", "Community_3", "Community_4", "Goals_1", "Career Opportunities_1", "Career Opportunities_2"])

laney_totals = total_multi(laney)

laney, laney_totals
# Out:
# ({'Values_1': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 5, 'ag': 4},
#   'Values_2': {'valid': 9, 'di': 0, 'sd': 0, 'n': 1, 'sa': 3, 'ag': 5},
#   'Values_3': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 3, 'ag': 6},
#   'SJ & Community_1': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 3, 'ag': 6},
#   'Community_1': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 5, 'ag': 4},
#   'Community_2': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 2, 'ag': 7},
#   'Community_3': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 2, 'ag': 7},
#   'Community_4': {'valid': 9, 'di': 0, 'sd': 1, 'n': 1, 'sa': 2, 'ag': 5},
#   'Goals_1': {'valid': 9, 'di': 0, 'sd': 1, 'n': 0, 'sa': 4, 'ag': 4},
#   'Career Opportunities_1': {'valid': 9,
#    'di': 0,
#    'sd': 0,
#    'n': 1,
#    'sa': 5,
#    'ag': 3},
#   'Career Opportunities_2': {'valid': 9,
#    'di': 0,
#    'sd': 0,
#    'n': 1,
#    'sa': 5,
#    'ag': 3}},
#  {'valid': 99, 'pos': 93, 'pos_with_n': 97})

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Positive: {}'.format(laney_totals["pos"]), 'Neutral: {}'.format(laney_totals["pos_with_n"] - laney_totals["pos"]), 'Other: {}'.format(laney_totals["valid"] - laney_totals["pos_with_n"])]

# creating percantages from data for visuals
per = (laney_totals["pos"] / laney_totals["valid"]) * 100
per2 = ((laney_totals["pos_with_n"] - laney_totals["pos"]) / laney_totals["valid"]) * 100
per3 = 100 - per - per2

size_of_groups = [per, per2, per3]

fig1, ax1 = plt.subplots()
ax1.pie(size_of_groups, colors=["tab:orange", "r", "c"], labels=labels, autopct='%1.1f%%',
        shadow=True)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.xlabel("Laney BUILD Learner Positive Responses")
plt.title("HtH Affective - Values, Goals, Community and Social Justice")
# plt.savefig('images/laneyb_affective_pie.png')
plt.show()

# %% [markdown]
# <b>Overall, there were 99 learner responses to the HtH Affective section of the survey. 93 (93.9%) were positive not including neutral responses. 97 (98%) were positive including neutral responses.</b>

# %%
# intersectional tech identity

laney = multi_response(laney1, ["Gee_1", "Gee_2", "Gee_3", "McAlpine_1", "McAlpine_2", "McAlpine_3", "McAlpine_4", "McAlpine_5"])

laney_totals = total_multi(laney)

laney, laney_totals
# Out:
# ({'Gee_1': {'valid': 9, 'di': 0, 'sd': 0, 'n': 1, 'sa': 2, 'ag': 6},
#   'Gee_2': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 3, 'ag': 6},
#   'Gee_3': {'valid': 9, 'di': 0, 'sd': 0, 'n': 1, 'sa': 5, 'ag': 3},
#   'McAlpine_1': {'valid': 9, 'di': 0, 'sd': 0, 'n': 1, 'sa': 3, 'ag': 5},
#   'McAlpine_2': {'valid': 9, 'di': 0, 'sd': 1, 'n': 1, 'sa': 3, 'ag': 4},
#   'McAlpine_3': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 4, 'ag': 5},
#   'McAlpine_4': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 5, 'ag': 4},
#   'McAlpine_5': {'valid': 9, 'di': 0, 'sd': 0, 'n': 0, 'sa': 3, 'ag': 6}},
#  {'valid': 72, 'pos': 67, 'pos_with_n': 71})

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Positive: {}'.format(laney_totals["pos"]), 'Neutral: {}'.format(laney_totals["pos_with_n"] - laney_totals["pos"]), 'Other: {}'.format(laney_totals["valid"] - laney_totals["pos_with_n"])]

# creating percantages from data for visuals
per = (laney_totals["pos"] / laney_totals["valid"]) * 100
per2 = ((laney_totals["pos_with_n"] - laney_totals["pos"]) / laney_totals["valid"]) * 100
per3 = 100 - per - per2

size_of_groups = [per, per2, per3]

fig1, ax1 = plt.subplots()
ax1.pie(size_of_groups, colors=["r", "c", "b"], labels=labels, autopct='%1.1f%%',
        shadow=True)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.xlabel("Laney BUILD Learner Positive Responses")
plt.title("Intersectional Tech Identity")
# plt.savefig('images/laneyb_identity_pie.png')
plt.show()

# %% [markdown]
# <b>Overall, there were 72 learner responses to the Intersectional Tech Identity section of the survey. 67 (93.1%) were positive not including neutral responses. 71 (98.6%) were positive including neutral responses.</b>
#
# <hr style="border:2px solid black">
#
# <b>Next we will be examining the learners responses to our inquiries about their ability to communicate about technology.</b> These questions are marked as the <b>QID1_1</b> and the <b>QID1_2</b> columns within the dataframe. Learners had five choices to choose from as their response to these questions: <b>Strongly Disagree, Somewhat Disagree, Somewhat Disagree, Strongly Agree</b>, and <b>Unsure or undecided.</b>
#
# <img src="images/laneyb_comm_just_tech.png" height=100% width=100%>

# %%
laney = multi_response(laney1, ["QID1_1", "QID1_2"])

laney_totals = total_multi(laney)

laney, laney_totals
# Out:
# ({'QID1_1': {'valid': 11, 'di': 0, 'sd': 0, 'n': 0, 'sa': 6, 'ag': 5},
#   'QID1_2': {'valid': 11, 'di': 0, 'sd': 1, 'n': 2, 'sa': 3, 'ag': 5}},
#  {'valid': 22, 'pos': 19, 'pos_with_n': 21})

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Positive: {}'.format(laney_totals["pos"]), 'Neutral: {}'.format(laney_totals["pos_with_n"] - laney_totals["pos"]), 'Other: {}'.format(laney_totals["valid"] - laney_totals["pos_with_n"])]

# creating percantages from data for visuals
per = (laney_totals["pos"] / laney_totals["valid"]) * 100
per2 = ((laney_totals["pos_with_n"] - laney_totals["pos"]) / laney_totals["valid"]) * 100
per3 = 100 - per - per2

size_of_groups = [per, per2, per3]

fig1, ax1 = plt.subplots()
ax1.pie(size_of_groups, colors=["c", "b", "m"], labels=labels, autopct='%1.1f%%',
        shadow=True)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.xlabel("Laney BUILD Learner Positive Responses")
plt.title("Communication about Technology")
# plt.savefig('images/laneyb_comm_just_tech_pie.png')
plt.show()

# %% [markdown]
# <b>Overall, there were 22 responses given from all learners. Of those responses, 21 (95.5%) were positive including neutral responses and 19 (86.4%) were positive not including neutral responses.</b>
#
# # I can communicate verbally or in writing to others about technology or programming.

# %%
get_responses(laney1, "QID1_1")
# Out:
# {'valid': 11, 'di': 0, 'sd': 0, 'n': 0, 'sa': 6, 'ag': 5}

# %% [markdown]
# <img src="images/laneyb_qid1_table.png" height=100% width=100%>
#
# # I can give a short talk to an audience about technology or programming.

# %%
get_responses(laney1, "QID1_2")
# Out:
# {'valid': 11, 'di': 0, 'sd': 1, 'n': 2, 'sa': 3, 'ag': 5}

# %% [markdown]
# <img src="images/laneyb_qid2_table.png" height=100% width=100%>
#
# <hr style="border:2px solid black">
#
# <b>Next we will be examining the learners responses to our inquiries about their general programming and computer science skills.</b> These questions are marked as the <b>Programming Skills_1, Programming Skills_2, Programming Skills_3, Programming Skills_1.1, Programming Skills_2.1,</b> and the <b>Programming Skills_3.1</b> columns within the dataframe. Learners had five choices to choose from as their response to these questions. For the first three, those choices were <b>Strongly Disagree, Somewhat Disagree, Somewhat Disagree, Strongly Agree</b>, and <b>Unsure or undecided.</b> For the last three, the choices were <b>Never, Rarely, Sometimes, Very often</b>, and <b>Alwayse.</b>
#
# <img src="images/laneyb_gen_cs.png" height=100% width=100%>
# <img src="images/laneyb_gen_cs2.png" height=100% width=100%>

# %%
laney = multi_response(laney1, ["Programming Skills_1", "Programming Skills_2", "Programming Skills_3", "Programming Skills_1.1", "Programming Skills_2.1", "Programming Skills_3.1"])

laney_totals = total_multi(laney)

laney, laney_totals
# Out:
# ({'Programming Skills_1': {'valid': 11,
#    'di': 0,
#    'sd': 0,
#    'n': 4,
#    'sa': 5,
#    'ag': 2},
#   'Programming Skills_2': {'valid': 11,
#    'di': 0,
#    'sd': 0,
#    'n': 1,
#    'sa': 3,
#    'ag': 7},
#   'Programming Skills_3': {'valid': 11,
#    'di': 0,
#    'sd': 0,
#    'n': 2,
#    'sa': 7,
#    'ag': 2},
#   'Programming Skills_1.1': {'valid': 11,
#    'n': 0,
#    'r': 1,
#    's': 4,
#    'v': 4,
#    'a': 2},
#   'Programming Skills_2.1': {'valid': 11,
#    'n': 0,
#    'r': 2,
#    's': 6,
#    'v': 3,
#    'a': 0},
#   'Programming Skills_3.1': {'valid': 11,
#    'n': 0,
#    'r': 1,
#    's': 5,
#    'v': 3,
#    'a': 2}},
#  {'valid': 66, 'pos': 55, 'pos_with_n': 62})

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['Positive: {}'.format(laney_totals["pos"]), 'Neutral: {}'.format(laney_totals["pos_with_n"] - laney_totals["pos"]), 'Other: {}'.format(laney_totals["valid"] - laney_totals["pos_with_n"])]

# creating percantages from data for visuals
per = (laney_totals["pos"] / laney_totals["valid"]) * 100
per2 = ((laney_totals["pos_with_n"] - laney_totals["pos"]) / laney_totals["valid"]) * 100
per3 = 100 - per - per2

size_of_groups = [per, per2, per3]

fig1, ax1 = plt.subplots()
ax1.pie(size_of_groups, colors=["b", "m", "y"], labels=labels, autopct='%1.1f%%',
        shadow=True)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.xlabel("Laney BUILD Learner Positive Responses")
plt.title("General Computer Science Skills")
# plt.savefig('images/laneyb_gen_cs_pie.png')
plt.show()

# %% [markdown]
# <b>Overall, there were 66 responses given from all learners. Of those responses, 62 (93.9%) were positive including neutral responses and 55 (83.3%) were positive not including neutral responses.</b>
#
# # I can write code to complete a simple task

# %%
get_responses(laney1, "Programming Skills_1")
# Out:
# {'valid': 11, 'di': 0, 'sd': 0, 'n': 4, 'sa': 5, 'ag': 2}

# %% [markdown]
# <img src="images/laneyb_program1_table.png" height=100% width=100%>
#
# # I increased my programming skills in this program.

# %%
get_responses(laney1, "Programming Skills_2")
# Out:
# {'valid': 11, 'di': 0, 'sd': 0, 'n': 1, 'sa': 3, 'ag': 7}

# %% [markdown]
# <img src="images/laneyb_program2_table.png" height=100% width=100%>
#
# # I can explain or storyboard a software idea that I have.

# %%
get_responses(laney1, "Programming Skills_3")
# Out:
# {'valid': 11, 'di': 0, 'sd': 0, 'n': 2, 'sa': 7, 'ag': 2}

# %% [markdown]
# <img src="images/laneyb_program3_table.png" height=100% width=100%>
#
# # When I have errors in my code, I know a few things to look for.

# %%
get_responses(laney1, "Programming Skills_1.1")
# Out:
# {'valid': 11, 'n': 0, 'r': 1, 's': 4, 'v': 4, 'a': 2}

# %% [markdown]
# <img src="images/laneyb_program4_table.png" height=100% width=100%>
#
# # When I write new code, I leave myself enough comments and notes to know what I did.

# %%
get_responses(laney1, "Programming Skills_1.1")

# %% [markdown]
# <img src="images/laneyb_program5_table.png" height=100% width=100%>
#
# # When I write new code, I leave myself enough comments and notes to know what I did.

# %%
laney1
# Out:
#          Q26 Verify          QID1_1               QID1_2 Programming Skills_1  \
# 2       DL23    Yes  Strongly agree       Strongly agree       Strongly agree
# 3       DL03    Yes  Somewhat agree    Somewhat disagree       Somewhat agree
# 4   30005761    Yes  Strongly agree       Strongly agree       Strongly agree
# 5       DL06    Yes  Somewhat agree       Somewhat agree       Somewhat agree
# 6    CFE2988    Yes  Strongly agree       Somewhat agree       Somewhat agree
# 7       DL08    Yes  Somewhat agree  Unsure or undecided       Somewhat agree
# 8   11012853    Yes  Strongly agree       Strongly agree  Unsure or undecided
# 9       DL13    Yes  Somewhat agree  Unsure or undecided  Unsure or undecided
# 10      DL24    Yes  Somewhat agree       Strongly agree       Somewhat agree
# 11  10958123    Yes  Strongly agree       Strongly agree  Unsure or undecided
# 12  30026156    Yes  Somewhat agree       Somewhat agree  Unsure or undecided
# 13       NaN    NaN             NaN                  NaN                  NaN
# 14       NaN    NaN             NaN                  NaN                  NaN
#
#    Programming Skills_2 Programming Skills_3 Programming Skills_1.1  \
# 2        Strongly agree       Strongly agree              Sometimes
# 3        Strongly agree  Unsure or undecided             Very often
# 4        Somewhat agree       Somewhat agree             Very often
# 5        Strongly agree       Strongly agree              Sometimes
# 6        Strongly agree       Somewhat agree                 Always
# 7        Strongly agree       Somewhat agree              Sometimes
# 8        Somewhat agree       Somewhat agree             Very often
# 9   Unsure or undecided  Unsure or undecided                 Rarely
# 10       Strongly agree       Somewhat agree             Very often
# 11       Somewhat agree       Somewhat agree              Sometimes
# 12       Strongly agree       Somewhat agree                 Always
# 13                  NaN                  NaN                    NaN
# 14                  NaN                  NaN                    NaN
#
#    Programming Skills_2.1 Programming Skills_3.1        Values_1  \
# 2               Sometimes              Sometimes  Strongly agree
# 3              Very often              Sometimes  Somewhat agree
# 4               Sometimes             Very often  Strongly agree
# 5               Sometimes              Sometimes  Strongly agree
# 6              Very often                 Always  Somewhat agree
# 7                  Rarely              Sometimes  Somewhat agree
# 8               Sometimes             Very often  Somewhat agree
# 9                  Rarely                 Rarely             NaN
# 10              Sometimes             Very often             NaN
# 11              Sometimes              Sometimes  Strongly agree
# 12             Very often                 Always  Somewhat agree
# 13                    NaN                    NaN             NaN
# 14                    NaN                    NaN             NaN
#
#                Values_2        Values_3 SJ & Community_1  \
# 2   Unsure or undecided  Strongly agree   Strongly agree
# 3        Strongly agree  Somewhat agree   Somewhat agree
# 4        Strongly agree  Strongly agree   Strongly agree
# 5        Strongly agree  Strongly agree   Strongly agree
# 6        Somewhat agree  Strongly agree   Strongly agree
# 7        Strongly agree  Strongly agree   Strongly agree
# 8        Strongly agree  Strongly agree   Somewhat agree
# 9                   NaN             NaN              NaN
# 10                  NaN             NaN              NaN
# 11       Somewhat agree  Somewhat agree   Strongly agree
# 12       Somewhat agree  Somewhat agree   Somewhat agree
# 13                  NaN             NaN              NaN
# 14                  NaN             NaN              NaN
#
#                                                                                                                                                                                                            SJ & Community  \
# 2                                                             Technology allows you to have clear influence over your community. It influence how we view the world and shape the ways we have used technology over time.
# 3                          I think technology can help my community in limitless ways. A random idea is making a general portal for all California CC's. This way the transfer process can be easier for uneasy students.
# 4                                                                                                     Technology especially when centered on the needs of underrepresented communities can bring up insights and justice.
# 5                                                                                                                                                                          help people become more aware about the world
# 6                                                                                                                                                                                   Helping reach out to our communities.
# 7                             There is many ways technology can help the community. One example would be since here in Richmond the air is very polluted. We can use technology to find a solution to help clean the air.
# 8   It create a lot of opportunities for a lot of people, for example most jobs now are demanding some type of skills through technology whether it a simple think like using Microsoft Word or a different applications.
# 9                                                                                                                                                                                                                     NaN
# 10                                                                                                                                                                                                                    NaN
# 11                                                                                                                                                                   Tech can help the community live a better lifestyle
# 12                                                                                                                                                                    Data is the new oil just need to direct it properly
# 13                                                                                                                                                                                                                    NaN
# 14                                                                                                                                                                                                                    NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              SJ & Community.1  \
# 2   A social-technical discussion would be college should be for free for students who are attending a four year university. The government should pay college students tuition to cover their fees and make it easier for students who have loans or student debt to pay. It would give college students better access to education without having to worry about their next pay date and allow them to continue learning. They should make General Education requirement like Math, Science, History, English. Art, etc. for free to help them complete their requirement in time for graduation without having to stress about paying for their classes. College should be free because education matters.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Something I've always wanted to work on is a smart mirror. My friend brought up the idea of working on the code behind it and the touch screen but it seemed too difficult. If anything, we'll try it out in the future.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Raise more awareness with high school students on how data science can be used as a tool for activism and drive change or create policy.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            the superhero battle simulator.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             What is the best way we can combat homelessness
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I'm not sure what specifically since there is so many options but I have always wanted to make something that we do everyday automated
# 8                                                                                                                                                                                                                                                        One project that I wanted to create  for the future in terms of wha hack the hood can integrate to programs that would make it even better. My plan was to have a hardware aspect of our current program , so we will still be coding but with what we put together. The idea is to have us learn and build our own pc's that we can use for the curriculum and make something out of it and hopefully we can keep them too after the program ends.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         NaN
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        NaN
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              social media
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Money allocation for community’s
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        NaN
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        NaN
#
#        Community_1     Community_2     Community_3          Community_4  \
# 2   Strongly agree  Strongly agree  Strongly agree       Strongly agree
# 3   Somewhat agree  Strongly agree  Strongly agree    Somewhat disagree
# 4   Somewhat agree  Strongly agree  Strongly agree       Strongly agree
# 5   Somewhat agree  Somewhat agree  Strongly agree       Somewhat agree
# 6   Strongly agree  Strongly agree  Somewhat agree       Somewhat agree
# 7   Somewhat agree  Strongly agree  Strongly agree  Unsure or undecided
# 8   Strongly agree  Strongly agree  Strongly agree       Strongly agree
# 9              NaN             NaN             NaN                  NaN
# 10             NaN             NaN             NaN                  NaN
# 11  Strongly agree  Strongly agree  Strongly agree       Strongly agree
# 12  Somewhat agree  Somewhat agree  Somewhat agree       Strongly agree
# 13             NaN             NaN             NaN                  NaN
# 14             NaN             NaN             NaN                  NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                            Community  \
# 2   My personal mentor Cindy! She has an outgoing and bubbly personally making talking fun and easy. She gave me personal insights on management and more technical roles to explore and gave me more clarity of each roles that made perfect sense. I was surprised to hear she was a pre-med major and with no technical background and was given a recommendation from her best friend to pursue a job into tech.
# 3                                                                                                                                                                                                                                                                                   My mentor didn't come to the kickoff meeting and when I reached out to them about their availability, they didn't respond to me.
# 4                                      I have been fortunate to connect well with my mentor. I appreciate the thoughtfulness of the Hack the Hood team to partner us up with a mentor with similar backgrounds, interests, and goals we have for a mentor/mentee connection. So far my mentor has helped me revamp my LinkedIn and evaluate which opportunities I should be looking/applying to for my career goals.
# 5                                                                                                                                                                                                                                                                                                                                                I didn't get to meet my mentor yet but I'm still talking with them.
# 6                                                                                                                                                                                                                                                                                                                                                                                     Havent met with my mentor yet.
# 7                                                                                                                                                                                                                                                                                                                                                                                              Have not met them yet
# 8                                                                                           Me and my mentor interaction went pretty well, we have a few things in common, when we talked we basically talked about what we were interested in, hobbies, upcoming things that we want to do. One thing that I learned is it always good to in a way give back to the community by like teacher others want you know.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                NaN
# 10                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 11                                                                                                                                                                                                                                                                                                          I met my mentor we had a good conversation we talked about the program and goals for when i attend laney
# 12                                                                                                                                                                                                                                                                                                                                                                      Very well and still talk to them once a week
# 13                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 14                                                                                                                                                                                                                                                                                                                                                                                                               NaN
#
#                                                                                                                                                                                                                                               Goals  \
# 2   The goals I set myself during this program was to attend all zoom meetings and compete all my assignments on time and plan possible questions to ask my mentor to help me understand my roles into tech in hopes of finding a career into tech.
# 3                                                                                                                                                                                          completing every assignment and attending every meeting.
# 4                                                                                                                                                                                                      to work and complete a data analysis project
# 5                                                                                                                                                          the goal I set fro myself during this program was completing it and learning new skills.
# 6                                                                                                                                                          The goal i set for myself during this program was to get the fundamentals of coding down
# 7                                                                                                                                                                                           Complete the program by showing up to class when I cam
# 8                                                                                                                                                     To figure if coding is something I really want to do and to expand my network and knowledge.
# 9                                                                                                                                                                                                                                               NaN
# 10                                                                                                                                                                                                                                              NaN
# 11                                                                                                                                                                                                                   Learn coding \nsocial justice
# 12                                                                                                                                                                                                                                   Fundamentals\n
# 13                                                                                                                                                                                                                                              NaN
# 14                                                                                                                                                                                                                                              NaN
#
#               Goals_1 Career Opportunities_1 Career Opportunities_2  \
# 2      Strongly agree         Strongly agree         Strongly agree
# 3   Somewhat disagree         Somewhat agree         Somewhat agree
# 4      Strongly agree    Unsure or undecided         Somewhat agree
# 5      Strongly agree         Somewhat agree         Strongly agree
# 6      Strongly agree         Strongly agree    Unsure or undecided
# 7      Somewhat agree         Somewhat agree         Somewhat agree
# 8      Somewhat agree         Somewhat agree         Somewhat agree
# 9                 NaN                    NaN                    NaN
# 10                NaN                    NaN                    NaN
# 11     Somewhat agree         Strongly agree         Strongly agree
# 12     Somewhat agree         Somewhat agree         Somewhat agree
# 13                NaN                    NaN                    NaN
# 14                NaN                    NaN                    NaN
#
#    Edu opportunity                Gee_1           Gee_2                Gee_3  \
# 2              NaN       Strongly agree  Strongly agree       Strongly agree
# 3              NaN  Unsure or undecided  Somewhat agree       Somewhat agree
# 4              NaN       Strongly agree  Strongly agree       Somewhat agree
# 5              NaN       Strongly agree  Strongly agree       Strongly agree
# 6              NaN       Somewhat agree  Somewhat agree       Strongly agree
# 7              NaN       Strongly agree  Strongly agree       Somewhat agree
# 8              NaN       Strongly agree  Strongly agree       Somewhat agree
# 9              NaN                  NaN             NaN                  NaN
# 10             NaN                  NaN             NaN                  NaN
# 11             NaN       Somewhat agree  Somewhat agree       Somewhat agree
# 12             NaN       Strongly agree  Strongly agree  Unsure or undecided
# 13             NaN                  NaN             NaN                  NaN
# 14             NaN                  NaN             NaN                  NaN
#
#              McAlpine_1           McAlpine_2      McAlpine_3      McAlpine_4  \
# 2        Strongly agree       Strongly agree  Strongly agree  Strongly agree
# 3        Somewhat agree       Somewhat agree  Somewhat agree  Somewhat agree
# 4        Strongly agree       Strongly agree  Strongly agree  Strongly agree
# 5        Strongly agree       Somewhat agree  Strongly agree  Strongly agree
# 6        Strongly agree       Strongly agree  Strongly agree  Somewhat agree
# 7   Unsure or undecided  Unsure or undecided  Somewhat agree  Somewhat agree
# 8        Strongly agree       Strongly agree  Somewhat agree  Somewhat agree
# 9                   NaN                  NaN             NaN             NaN
# 10                  NaN                  NaN             NaN             NaN
# 11       Somewhat agree    Somewhat disagree  Somewhat agree  Somewhat agree
# 12       Somewhat agree       Somewhat agree  Strongly agree  Strongly agree
# 13                  NaN                  NaN             NaN             NaN
# 14                  NaN                  NaN             NaN             NaN
#
#         McAlpine_5  \
# 2   Strongly agree
# 3   Somewhat agree
# 4   Strongly agree
# 5   Strongly agree
# 6   Strongly agree
# 7   Strongly agree
# 8   Somewhat agree
# 9              NaN
# 10             NaN
# 11  Somewhat agree
# 12  Strongly agree
# 13             NaN
# 14             NaN
#
#                                                                                                           Crenshaw  \
# 2                                       I am an Asian American women who is pursuing a degree in computer science.
# 3                                                                                          ambitious, eager & kind
# 4       a low-income, first-generation, bilingual, Latina college student who was born and raised in the Bay Area.
# 5                                                     a Mexican and Peruvian male in a lower middle class family.
# 6                                        A Hispanic first generation college student. I want to make my dad proud
# 7                                                                                I am a Hispanic, male from mexico
# 8   Black/ African, Male, sophomore in college, middle class, some of my privileges is that I am able body, male.
# 9                                                                                                              NaN
# 10                                                                                                             NaN
# 11                                                                  I am young black women with many opportunites
# 12                                                                                                    Hispanic him
# 13                                                                                                             NaN
# 14                                                                                                             NaN
#
#                                                                                                                                                                                                          Crenshaw.1  \
# 2                                                    I am a women in the stem field who is going to change the world around me with the help of technology in hopes to inspire others to pursue a career into tech.
# 3                                                                                                                                               A privileged student that has a lot to offer but needs to prove it.
# 4   often involved in spaces in which people who have similar backgrounds, have been historically excluded from. I am a straight Latina college-educated woman. I am a leader, justice seeker, and curious thinker.
# 5                                                                                                                                   I am a graduated high school student and eager to learn abut computer sciences
# 6                                                                                                                                                                                     Not sure what is being asked?
# 7                                                                                                                                                          I am someone who will bring change and help my community
# 8                There's not much I can say my identity at least not too different from the way I describe myself, beside being African and I kind of take pride in that, technology enthusiast, smart and reliable
# 9                                                                                                                                                                                                               NaN
# 10                                                                                                                                                                                                              NaN
# 11                                                                                                                                                                                             I am straight women
# 12                                                                                                                                                                                                              Him
# 13                                                                                                                                                                                                              NaN
# 14                                                                                                                                                                                                              NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                 Crenshaw.2  \
# 2   I love to connect with others in a deeper level to create meaningful connections to understand the world around us and stories we face in our community to help those who are silence by society to share their stories and  let them be heard by spreading their message using technology to fight and change the way we view the world in hopes of building a better and safer environment  to live.
# 3                                                                                                                                                                                                                                                                                                        I am eager to learn. If I want something desperately, I'll take the necessary steps to get there.
# 4                                                                                                                                                                                                                                                                                                                                          I am rooted in community values, well organized, and adaptable.
# 5                                                                                                                                                                                                                                                                                                                                                  I want to help people in any way I can with technology.
# 6                                                                                                                                                                                                                                                                                                  I am a hardworker, stubborn to make everything as perfect as it can be, a learner, and an overachiever
# 7                                                                                                                                                                                                                                                                                                                                                           Motivated, driven, dedicated, problem solving
# 8                                                                                                                                                                                                                                                                         very confident in my knowledge and honest, consistent, and resistant once I decide to do a task I would do my best to finish it.
# 9                                                                                                                                                                                                                                                                                                                                                                                                      NaN
# 10                                                                                                                                                                                                                                                                                                                                                                                                     NaN
# 11                                                                                                                                                                                I am a intelligent black women who wants to use tech as a platform to create awareness of issue in the community's that we live in. I think i should be interviews because i have learned the basic skills to gain data
# 12                                                                                                                                                                                                                                                                                                                                                                                    Experience and goals
# 13                                                                                                                                                                                                                                                                                                                                                                                                     NaN
# 14                                                                                                                                                                                                                                                                                                                                                                                                     NaN
#
#    Any last thoughts?_1 Any last thoughts?_2  \
# 2        Strongly agree       Strongly agree
# 3        Somewhat agree       Strongly agree
# 4        Strongly agree       Strongly agree
# 5        Strongly agree       Somewhat agree
# 6     Strongly disagree    Strongly disagree
# 7        Strongly agree       Strongly agree
# 8        Strongly agree       Strongly agree
# 9                   NaN                  NaN
# 10                  NaN                  NaN
# 11    Strongly disagree    Strongly disagree
# 12    Somewhat disagree    Somewhat disagree
# 13                  NaN                  NaN
# 14                  NaN                  NaN
#
#                                                                                                                                                                                                                                                                                                                                Why recommend  \
# 2                                                   I learn a lot throughout this program by posting all my coding assignments into GitHub to help build my portfolio on projects and assignments I did in Hack the Hood that would be beneficial of finding jobs into tech that would showcase my knowledge of coding and build my resume.
# 3                                                                                                                                               If  friend, relative is trying to break into tech, Hack the Hood should be a good place to start. Although the program moved rathe quickly, I was able to take away a lot from this program.
# 4                                                                                                                                                                                                         I would recommend this program because it is accessible and geared towards BIPOC folk who want to learn and break into technology.
# 5                                                                                                                                                                                                                                                  the program is amazing but covers material fast and people might not know how to keep up.
# 6                                                                                                                                                                                                                                      It is a good place to start your career in the tech industry. And good teachers to help along the way
# 7                                                                                                                                             I would recommend hack the hood to everyone that has any intrest in tech. Hack the hood is a good organization that provides many resources to people who would have a hard time finding them.
# 8   Personally I would recommend it because you it helps figure out what you want to do career wise if you haven't make a decision yet, or even if you have figure it out I would still say to do it because it doesn't hurt to expand an unknown domain even if your not familiar with it, because you get paid while learning so why not.
# 9                                                                                                                                                                                                                                                                                                                                        NaN
# 10                                                                                                                                                                                                                                                                                                                                       NaN
# 11                                                                                                                                                                                                                                                                 If someone is willing to attend the program they will gain coding skills
# 12                                                                                                                                                                                                                                                                                                                                      8/10
# 13                                                                                                                                                                                                                                                                                                                                       NaN
# 14                                                                                                                                                                                                                                                                                                                                       NaN
#
#                                                                                                                                                               Open  \
# 2                                              I enjoy Hack The Hood! This program gave me inspiration to use technology to help solve problems in our community.
# 3                                                                                                                                         No concerns or opinions.
# 4                                                                                                                                                              NaN
# 5                                                                                                                                 I liked it and am glad I joined.
# 6                                                                                                         Amazing program thank you for all the help you offer me.
# 7                                                                                                                                                              NaN
# 8   No nothing beside it being during covid there no concerns the program was enjoyable , the only thing I would change would that the learning was more hands on.
# 9                                                                                                                                                              NaN
# 10                                                                                                                                                             NaN
# 11                                                                                                                                                   no thank you
# 12                                                                                                            Peoples willingness to participate and share screen
# 13                                                                                                                                                             NaN
# 14                                                                                                                                                             NaN
#
#     SC0
# 2   137
# 3   112
# 4   134
# 5   130
# 6   124
# 7   119
# 8   128
# 9    22
# 10   33
# 11  114
# 12  119
# 13  NaN
# 14  NaN
